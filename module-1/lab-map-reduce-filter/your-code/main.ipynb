# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# import reduce from functools, numpy and pandas
import functools as reduce
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up a words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# Your code here:
print(list(map(lambda x:(x for x in prophet if x<568), prophet)))
# Out:
# [<generator object <lambda>.<locals>.<genexpr> at 0x11b5cb270>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb3c0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb350>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb2e0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb430>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb4a0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb510>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb580>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb5f0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb660>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb6d0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb740>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb7b0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb820>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb890>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb900>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb970>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cb9e0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cba50>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbac0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbb30>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbba0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbc10>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbc80>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbcf0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbd60>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbdd0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbe40>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbeb0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbf20>, <generator object <lambda>.<locals>.<genexpr> at 0x11b5cbf90>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609040>, <generator object <lambda>.<locals>.<genexpr> at 0x11b6090b0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609120>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609190>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609200>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609270>, <generator object <lambda>.<locals>.<genexpr> at 0x11b6092e0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609350>, <generator object <lambda>.<locals>.<genexpr> at 0x11b6093c0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609430>, <generator object <lambda>.<locals>.<genexpr> at 0x11b6094a0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609510>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609580>, <generator object <lambda>.<locals>.<genexpr> at 0x11b6095f0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609660>, <generator object <lambda>.<locals>.<genexpr> at 0x11b6096d0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609740>, <generator object <lambda>.<locals>.<genexpr> at 0x11b6097b0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609820>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609890>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609900>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609970>, <generator object <lambda>.<locals>.<genexpr> at 0x11b6099e0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609a50>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609ac0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609b30>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609ba0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609c10>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609c80>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609cf0>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609d60>, <generator object <lambda>.<locals>.<genexpr> at 0x11b609dd0>, <generator object <lambda>.<lo ...

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# Your code here:

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    
    # Your code here:

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`

# %%
# Your code here:

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # Your code here:

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# Your code here:

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# Your code here:

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: true if the word is not in the specified list and false if the word is in the list
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
   
  """  word_list = ['and', 'the', 'a', 'an']
    
    result=filter(: False if x in word_list else True, word_list)
    print(result)"""
    
def es_par(n):
    return n % 2 == 0
list(filter(es_par, range(1, 51)))"""

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %% [markdown]
# # Bonus Challenge - Part 1
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # Your code here:

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# Your code here:

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will load a dataset below and then write a function that will perform the transformation.

# %%
# Run this code:

# The dataset below contains information about pollution from PM2.5 particles in Beijing 

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
pm25 = pd.read_csv(url)

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# Your code here:

display(head(pm25))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-fda412a2c2df> in <module>
#       1 # Your code here:
#       2
# ----> 3 display(head(pm25))
#
# NameError: name 'head' is not defined

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    
    # Your code here:

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# Your code here:

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # Your code here:
