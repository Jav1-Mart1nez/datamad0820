# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity"

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1.head()
# Out:
#              sku                                               name  \
# 0  DI122G0M1-K11                        THOMMER - Jean slim - 0853p
# 1  AD115B01K-Q11                STAN SMITH - Baskets basses - black
# 2  N1242A1XA-Q12  PG 4 - Chaussures de basket - black/university...
# 3  PI922Q00A-Q11                                   Pullover - black
# 4  JA222G0W2-K11       JJIGLENN JJORIGINAL - Jean slim - blue denim
#
#                                                sizes  \
# 0  [27x32, 27x34, 30x32, 31x30, 31x32, 31x34, 32x...
# 1  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# 2  [35.5, 36.5, 39, 40, 40.5, 41, 42, 42.5, 43, 4...
# 3                   [XS, S, M, L, XL, XXL, 5XL, 6XL]
# 4  [28x30, 29x30, 29x32, 29x34, 30x30, 30x32, 30x...
#
#                                              url_key  \
# 0       diesel-thommer-jean-slim-0853p-di122g0m1-k11
# 1  adidas-originals-stan-smith-baskets-basses-ad1...
# 2  nike-performance-pg-4-chaussures-de-basket-n12...
# 3               pier-one-pullover-noir-pi922q00a-q11
# 4  jack-and-jones-jjiglenn-jjoriginal-jean-slim-b...
#
#                                                media        brand_name  \
# 0  [{'path': 'spp-media-p1/dc496b78584232f2823db6...            Diesel
# 1  [{'path': 'spp-media-p1/21edfdb7147b34e784cdd7...  adidas Originals
# 2  [{'path': 'spp-media-p1/9e53e69c593738328da7f4...  Nike Performance
# 3  [{'path': 'spp-media-p1/d46d22bf1cd8326e831ea8...          Pier One
# 4  [{'path': 'spp-media-p1/47ce66518c9c3107999dce...      Jack & Jones
#
#    is_premium family_articles  \
# 0       False              []
# 1       False              []
# 2       False              []
# 3       False              []
# 4       False              []
#
#                                                flags product_group  \
# 0  [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 1  [{'key': 'discountRate', 'value': 'Jusqu’à -15...          shoe
# 2  [{'key': 'discountRate', 'value': 'Jusqu’à -45...          shoe
# 3  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 4  [{'key': 'discountRate', 'value': 'Jusqu’à -10...      clothing
#
#   delivery_promises price.original price.promotional  \
# 0                []       129,95 €           90,95 €
# 1                []        94,95 €           80,45 €
# 2                []       119,95 €           65,95 €
# 3                []        22,99 €           18,39 €
# 4                []        39,99 €           35,99 €
#
#    price.has_different_prices  price.has_different_original_prices  \
# 0                       False                                False
# 1                        True                                False
# 2                        True                                False
# 3                       False                                False
# 4                        True                                False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                    True
# 2                                    True
# 3                                   False
# 4                                    True
#
#    price.has_discount_on_selected_sizes_only outfits
# 0                                      False     NaN
# 1                                      False     NaN
# 2                                      False     NaN
# 3                                      False     NaN
# 4                                      False     NaN

# %%
#He seleccionado 300 paginas porque no cargaba las 600 y pico.

# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(301):
    k=84*i
    url="https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity"
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {300}", end='\r')

df.head()
# Out:
# getting page 300 of 300
#                                                             name  \
# sku
# TOB22G00X-K11  SCANTON BEMB - Jean slim - berry mid blue comfort
# NI122S0AS-K11  Club Hoodie - Sweat à capuche - midnight navy/...
# AD115B01K-Q11                STAN SMITH - Baskets basses - black
# N1242A1XA-Q12  PG 4 - Chaussures de basket - black/university...
# PI922Q00A-Q11                                   Pullover - black
#
#                                                            sizes  \
# sku
# TOB22G00X-K11  [27x30, 27x32, 27x34, 27x36, 28x30, 28x32, 28x...
# NI122S0AS-K11                              [S, L, XXL, 3XL, 4XL]
# AD115B01K-Q11  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# N1242A1XA-Q12  [35.5, 36.5, 39, 40, 40.5, 41, 42, 42.5, 43, 4...
# PI922Q00A-Q11                   [XS, S, M, L, XL, XXL, 5XL, 6XL]
#
#                                                          url_key  \
# sku
# TOB22G00X-K11  tommy-jeans-scanton-bemb-jean-slim-berry-mid-b...
# NI122S0AS-K11  nike-sportswear-club-hoodie-sweatshirt-ni122s0...
# AD115B01K-Q11  adidas-originals-stan-smith-baskets-basses-ad1...
# N1242A1XA-Q12  nike-performance-pg-4-chaussures-de-basket-n12...
# PI922Q00A-Q11               pier-one-pullover-noir-pi922q00a-q11
#
#                                                            media  \
# sku
# TOB22G00X-K11  [{'path': 'spp-media-p1/8ce377485d3432fabcaafc...
# NI122S0AS-K11  [{'path': 'spp-media-p1/010fd18885323c1dbcabe4...
# AD115B01K-Q11  [{'path': 'spp-media-p1/21edfdb7147b34e784cdd7...
# N1242A1XA-Q12  [{'path': 'spp-media-p1/9e53e69c593738328da7f4...
# PI922Q00A-Q11  [{'path': 'spp-media-p1/d46d22bf1cd8326e831ea8...
#
#                      brand_name  is_premium family_articles  \
# sku
# TOB22G00X-K11       Tommy Jeans       False              []
# NI122S0AS-K11   Nike Sportswear       False              []
# AD115B01K-Q11  adidas Originals       False              []
# N1242A1XA-Q12  Nike Performance       False              []
# PI922Q00A-Q11          Pier One       False              []
#
#                                                            flags  \
# sku
# TOB22G00X-K11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# NI122S0AS-K11  [{'key': 'discountRate', 'value': '-10%', 'tra...
# AD115B01K-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -15...
# N1242A1XA-Q12  [{'key': 'discountRate', 'value': 'Jusqu’à -45...
# PI922Q00A-Q11  [{'key': 'discountRate', 'value': '-20%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# TOB22G00X-K11      clothing                []        99,95 €
# NI122S0AS-K11      clothing                []        49,95 €
# AD115B01K-Q11          shoe                []        94,95 €
# N1242A1XA-Q12          shoe                []       119,95 €
# PI922Q00A-Q11      clothing                []        22,99 €
#
#               price.promotional  price.has_different_prices  \
# sku
# TOB22G00X-K11           79,95 €                       False
# NI122S0AS-K11           44,95 €                       False
# AD115B01K-Q11           80,45 €                        True
# N1242A1XA-Q12           65,95 €                        True
# PI922Q00A-Q11           18,39 €                       False
#
#                price.has_different_original_prices  \
# sku
# TOB22G00X-K11                                False
# NI122S0AS-K11                                False
# AD115B01K-Q11                                False
# N1242A1XA-Q12                                False
# PI922Q00A-Q11                                False
#
#                price.has_different_promotional_prices  \
# sku
# TOB22G00X-K11                                   False
# NI122S0AS-K11                                   False
# AD115B01K-Q11                                    True
# N1242A1XA-Q12                                    True
# PI922Q00A-Q11                                   False
#
#                price.has_discount_on_selected_sizes_only outfits
# sku
# TOB22G00X-K11                                      False     NaN
# NI122S0AS-K11                                      False     NaN
# AD115B01K-Q11                                      False     NaN
# N1242A1XA-Q12                                      False     NaN
# PI922Q00A-Q11                                      False     NaN

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
df = df.drop_duplicates()

# ¿¿No se pueden eliminar los registros duplicados??
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-032cff854eaf> in <module>
# ----> 1 df = df.drop_duplicates()
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    5100
#    5101         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 5102         duplicated = self.duplicated(subset, keep=keep)
#    5103
#    5104         result = self[-duplicated]
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    5238
#    5239         vals = (col.values for name, col in self.items() if name in subset)
# -> 5240         labels, shape = map(list, zip(*map(f, vals)))
#    5241
#    5242         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in f(vals)
#    5212
#    5213         def f(vals):
# -> 5214             labels, shape = algorithms.factorize(
#    5215                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT)
#    5216             )
#
# /usr/local/lib/python3.8/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint, dropna)
#     645             na_value = None
#     646
# --> 647         codes, uniques = _factorize_array(
#     648             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     649         )
#
# /usr/local/lib/python3.8/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     493
#     494     table = hash_klass(size_hint or len(values))
# --> 495     uniques, codes = table.factorize(
#     496         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     497     )
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
# The trending brand.

df["brand_name"].value_counts().index[0]
# Out:
# 'Pier One'

# %%
# The product(s) with the highest discount.

df["price.promotional"] = [promotional.replace(",",".").replace("€","").replace(" ","") for promotional in df["price.promotional"]]
df["price.original"] = [original.replace(",",".").replace("€","").replace(" ","") for original in df["price.original"]]

# %%
df["discount"] = round(1-(df["price.promotional"].astype(float)/df["price.original"].astype(float)),2)
df = df.sort_values("discount", ascending = False)
print(df["brand_name"][0])
display(df.head())
# Out:
# Pier One
#                                             name       sizes  \
# sku
# PI952H04S-K11  UNISEX - Cabas - dark blue/cognac  [One Size]
# PI952H04S-K11  UNISEX - Cabas - dark blue/cognac  [One Size]
# PI952H04S-K11  UNISEX - Cabas - dark blue/cognac  [One Size]
# PI952H04S-K11  UNISEX - Cabas - dark blue/cognac  [One Size]
# PI952H04S-K11  UNISEX - Cabas - dark blue/cognac  [One Size]
#
#                                                     url_key  \
# sku
# PI952H04S-K11  pier-one-cabas-dark-bluecognac-pi952h04s-k11
# PI952H04S-K11  pier-one-cabas-dark-bluecognac-pi952h04s-k11
# PI952H04S-K11  pier-one-cabas-dark-bluecognac-pi952h04s-k11
# PI952H04S-K11  pier-one-cabas-dark-bluecognac-pi952h04s-k11
# PI952H04S-K11  pier-one-cabas-dark-bluecognac-pi952h04s-k11
#
#                                                            media brand_name  \
# sku
# PI952H04S-K11  [{'path': 'spp-media-p1/383cc12fe4cb353e8b24df...   Pier One
# PI952H04S-K11  [{'path': 'spp-media-p1/383cc12fe4cb353e8b24df...   Pier One
# PI952H04S-K11  [{'path': 'spp-media-p1/383cc12fe4cb353e8b24df...   Pier One
# PI952H04S-K11  [{'path': 'spp-media-p1/383cc12fe4cb353e8b24df...   Pier One
# PI952H04S-K11  [{'path': 'spp-media-p1/383cc12fe4cb353e8b24df...   Pier One
#
#                is_premium family_articles  \
# sku
# PI952H04S-K11       False              []
# PI952H04S-K11       False              []
# PI952H04S-K11       False              []
# PI952H04S-K11       False              []
# PI952H04S-K11       False              []
#
#                                                            flags  \
# sku
# PI952H04S-K11  [{'key': 'discountRate', 'value': '-60%', 'tra...
# PI952H04S-K11  [{'key': 'discountRate', 'value': '-60%', 'tra...
# PI952H04S-K11  [{'key': 'discountRate', 'value': '-60%', 'tra...
# PI952H04S-K11  [{'key': 'discountRate', 'value': '-60%', 'tra...
# PI952H04S-K11  [{'key': 'discountRate', 'value': '-60%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# PI952H04S-K11   accessoires                []         26.99
# PI952H04S-K11   accessoires                []         26.99
# PI952H04S-K11   accessoires                []         26.99
# PI952H04S-K11   accessoires                []         26.99
# PI952H04S-K11   accessoires                []         26.99
#
#               price.promotional  price.has_different_prices  \
# sku
# PI952H04S-K11            10.89                        False
# PI952H04S-K11            10.89                        False
# PI952H04S-K11            10.89                        False
# PI952H04S-K11            10.89                        False
# PI952H04S-K11            10.89                        False
#
#                price.has_different_original_prices  \
# sku
# PI952H04S-K11                                False
# PI952H04S-K11                                False
# PI952H04S-K11                                False
# PI952H04S-K11                                False
# PI952H04S-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# PI952H04S-K11                                   False
# PI952H04S-K11                                   False
# PI952H04S-K11                                   False
# PI952H04S-K11                                   False
# PI952H04S-K11                                   False
#
#                price.has_discount_on_selected_sizes_only outfits  discount
# sku
# PI952H04S-K11                                      False     NaN       0.6
# PI952H04S-K11                                      False     NaN       0.6
# PI952H04S-K11                                      False     NaN       0.6
# PI952H04S-K11                                      False     NaN       0.6
# PI952H04S-K11                                      False     NaN       0.6

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

sum_discount = round(1-(df["price.promotional"].astype(float).sum()/df["price.original"].astype(float).sum()),2)
print(sum_discount)
# Out:
# 0.23
